# %%
import pandas as pd
import re
tags= pd.read_csv('tags.csv',header=0)
df_books = pd.read_csv('books.csv',header =0)
df_ratings = pd.read_csv('ratings.csv',header = 0)
df_booktags = pd.read_csv('book_tags.csv',header =0)
to_read_data = pd.read_csv('to_read.csv',header=0)

# %% [markdown]
# ### Tags Data
# ###### This section deals with the tags data to extract the tags related to each book, and then use it as a variable in the books final dataset, which is created later

# %%
#extracting tags from the tag name column
tags['tag_cleaned']=tags['tag_name'].str.extract(r"([a-z].*)", expand=False)

# %%
tags.dtypes
# Out:
# tag_id          int64
# tag_name       object
# tag_cleaned    object
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
#tags.groupby('new').count()[['tag_id']].sort_values(['tag_id'],ascending=False)

# %%
df_booktags = pd.read_csv('book_tags.csv',header =0)

# %%
df_booktags.head()
# Out:
#    book_id  tag_id   count
# 0        1   30574  167697
# 1        1   11305   37174
# 2        1   11557   34173
# 3        1    8717   12986
# 4        1   33114   12716

# %%
tags.head()
# Out:
#    tag_id tag_name tag_cleaned
# 0       0        -         NaN
# 1       1     --1-         NaN
# 2       2    --10-         NaN
# 3       3    --12-         NaN
# 4       4   --122-         NaN

# %%
#merge extracted tags with the booktags dataset containing tag ids only, to get the actual tag in words
tags_data = pd.merge(df_booktags, tags, how='left', on='tag_id')

# %%
tags_data.shape
# Out:
# (999912, 5)

# %%
tags_data = tags_data[['book_id','count','tag_id','tag_cleaned']]

# %%
df_booktags['book_id'].nunique()
# Out:
# 10000

# %%
#selecting the tag with highest count of tags for each book
td=tags_data.sort_values(by=['book_id','count'],ascending=[1,0]).groupby('book_id').head(1)

# %%
td.head(100)
# Out:
#       book_id   count  tag_id        tag_cleaned
# 0           1  167697   30574            to-read
# 100         2   24549   30574            to-read
# 200         3  496107   30574            to-read
# 300         5   40087   11557          favorites
# 400         6   38378   11305            fantasy
# 500         8    2823   30574            to-read
# 600        10    3226   30574            to-read
# 700        11   32303   30574            to-read
# 800        13   75870   30574            to-read
# 900        21   33603   30574            to-read
# 1000       24    2312   31155             travel
# 1100       25     816   30574            to-read
# 1200       26   27858   30574            to-read
# 1300       27   31357   30574            to-read
# 1400       28   35420   30574            to-read
# 1500       29    5492   30574            to-read
# 1600       30     692   30574            to-read
# 1700       33  116442   30574            to-read
# ...

# %%
tags_data['goodreads_book_id'].count()
# Out:
# 10000

# %% [markdown]
# ### To Read Dataset
# #### Using this dataset to get a count of how many times each book has been put in the to-read list

# %%
to_read_data.head()
# Out:
#    user_id  book_id
# 0        1      112
# 1        1      235
# 2        1      533
# 3        1     1198
# 4        1     1874

# %%
#final to-read dataset with counts for each book-id
trd=to_read_data.groupby('book_id').count()[['user_id']].reset_index()

# %%
trd.head()
# Out:
#    book_id  user_id
# 0        1      973
# 1        2      400
# 2        3      287
# 3        4     1478
# 4        5     1293

# %%
trd['book_id'].nunique()
# Out:
# 9986

# %% [markdown]
# ### Merging the datasets created above - tags data and to read data- with the books datatset to create a final dataset with all features

# %%
data_frames = [df_books,td[['tag_cleaned','book_id']],trd[['user_id','book_id']]]
from functools import reduce

# %%
book_data_final = reduce(lambda  left,right: pd.merge(left,right,on=['book_id'],
                                            how='left'), data_frames).fillna('void')

# %%
book_data_final.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn       isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.78044e+12
# 1   2        3             3  4640799          491  439554934  9.78044e+12
# 2   3    41865         41865  3212258          226  316015849  9.78032e+12
# 3   4     2657          2657  3275794          487   61120081  9.78006e+12
# 4   5     4671          4671   245494         1356  743273567  9.78074e+12
#
#                        authors original_publication_year  \
# 0              Suzanne Collins                      2008
# 1  J.K. Rowling, Mary GrandPré                      1997
# 2              Stephenie Meyer                      2005
# 3                   Harper Lee                      1960
# 4          F. Scott Fitzgerald                      1925
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# ...

# %%
book_data_final.shape
# Out:
# (10000, 25)
